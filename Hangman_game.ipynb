# %% [markdown]
# <a href="https://colab.research.google.com/github/meenupannnu/Hangman-Game/blob/main/Hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def get_random_word(filename):
    with open(filename, 'r') as file:
        words = file.readlines()
    words = [word.strip() for word in words] # extraxt words
    return random.choice(words)

def get_hangman_stages(filename):
    with open(filename, 'r') as file:
        stages = file.read().split('###')  #split
    return stages

def display_hangman(stages, tries):
    return stages[tries]

def play_game(words_file, stages_file):
    word = get_random_word(words_file)
    stages = get_hangman_stages(stages_file)
    word_letters = set(word)  # Letters in the word
    guessed_letters = set()  # Letters guessed by the user
    correct_letters = set()  # Correctly guessed letters
    tries = 6  # Reduced number of tries

    print("Let's play Hangman!")
    print(display_hangman(stages, tries))
    print("_ " * len(word))

    while tries > 0:
        print("tries ", tries)
        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please guess a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.add(guess)

        if guess in word_letters:
            correct_letters.add(guess)
            print(f"Good job! '{guess}' is in the word.")
        else:
            tries -= 1
            print(f"Sorry, '{guess}' is not in the word. You have {tries} tries left.") # f is to treta guess as variable not string
            print(display_hangman(stages, tries))

        # Display the current state of the word
        current_word = [letter if letter in correct_letters else '_' for letter in word] #space
        print(" ".join(current_word))

        if correct_letters == word_letters:
            print(f"Congratulations! You've guessed the word '{word}' correctly.")
            return

    print(f"Game over! The word was '{word}'.")

if __name__ == "__main__":
    words_file = 'words.txt'
    stages_file = 'stages.txt'
    play_game(words_file, stages_file)
# Out:
# Let's play Hangman!
#
# -----
# |   |
# O   |
# /|\\ |
# / \\ |
#     |
# --------
#
# _ _ _ _
# tries  6
# Guess a letter: D
# Sorry, 'd' is not in the word. You have 5 tries left.
#
# -----
# |   |
# O   |
# /|\\ |
# /   |
#     |
# --------
#
# _ _ _ _
# tries  5
# Guess a letter: A
# Good job! 'a' is in the word.
# _ a _ a
# tries  5
# Guess a letter: B
# Sorry, 'b' is not in the word. You have 4 tries left.
#
# -----
# |   |
# O   |
# /|\\ |
#     |
#     |
# --------
#
# _ a _ a
# tries  4
# Guess a letter: M
# Sorry, 'm' is not in the word. You have 3 tries left.
#
# -----
# |   |
# O   |
# /|  |
#     |
#     |
# --------
#
# _ a _ a
# tries  3
# Guess a letter: V
# Good job! 'v' is in the word.
# _ a v a
# tries  3
# Guess a letter: T
# Sorry, 't' is not in the word. You have 2 tries left.
#
# -----
# |   |
# O   |
# |   |
#     |
#     |
# --------
#
# _ a v a
# tries  2
# Guess a letter: F
# Sorry, 'f' is not in the word. You have 1 tries left.
#
# -----
# |   |
# O   |
#     |
#     |
#     |
# --------
#
# _ a v a
# tries  1
# Guess a letter: H
# Sorry, 'h' is not in the word. You have 0 tries left.
# -----
# |   |
#     |
#     |
#     |
#     |
# --------
#
# _ a v a
# Game over! The word was 'java'.
